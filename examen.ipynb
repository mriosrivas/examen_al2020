# %%
import numpy as np

import matplotlib.pyplot as plt
import matplotlib
from matplotlib.patches import Polygon
from matplotlib.collections import PatchCollection

# %%
def generatePolygons(triangles):
    patches = []
    
    for i in triangles:
        polygon = Polygon(i[:,0:2], True)
        patches.append(polygon)
        
    p = PatchCollection(patches, cmap=matplotlib.cm.jet, alpha=0.4)
    colors = 100*np.random.rand(len(patches))
    p.set_array(np.array(colors))
    return p

# %%
bigTriangle = np.array([[0.5, 0.5, 1],[1.5, 0.5, 1], [1, 1.5, 1]])
smallTriangle = np.array([[1.0, 1.0, 1], [0.875, 1.25, 1], [1, 1.5, 1], [1.125, 1.25, 1]])
triangles = [bigTriangle, smallTriangle]

# %%
##################################################################################################################
#################################### Solo tienes que editar aquí =D ##############################################
h = 5
k = 5
T = np.array([[1, 0, h], [0, 1, k], [0, 0, 1]]);

angle = np.pi/4
R = np.array([[np.cos(angle), -np.sin(angle), 0], [np.sin(angle), np.cos(angle), 0], [0, 0, 1]])
##################################################################################################################

# %%
newBigTriangle = T@R@bigTriangle.T
newSmallTriangle = T@R@smallTriangle.T
newTriangles = [newBigTriangle.T, newSmallTriangle.T]

# %%
p = generatePolygons(triangles)
q = generatePolygons(newTriangles)

plt.rcParams["figure.figsize"] = (12,12)
fig, ax = plt.subplots()
ax.set_xlim(-2,10)
ax.set_ylim(-2,10)
ax.add_collection(p)
ax.add_collection(q)
ax.minorticks_on()
ax.grid(True)
ax.grid(which='minor', linestyle=':', linewidth='0.5', color='black')
